# %%
from smac.env import StarCraft2Env
import numpy as np


def run_test():
    env = StarCraft2Env(map_name="MMM")
    env_info = env.get_env_info()

    n_actions = env_info["n_actions"]
    n_agents = env_info["n_agents"]
   
    print('env info: ', env_info)
    n_episodes = 1

    for e in range(n_episodes):
        obs, state = env.reset()
        print(np.shape(state))
        terminated = False
        episode_reward = 0

        while not terminated:
            obs = env.get_obs()
            state = env.get_state()
            print(np.shape(state))
            actions = []
            for agent_id in range(n_agents):
                
                avail_actions = env.get_avail_agent_actions(agent_id)
                avail_actions_ind = np.nonzero(avail_actions)[0]
                action = np.random.choice(avail_actions_ind)
                actions.append(action)

            reward, terminated, info = env.step(actions)
            
            episode_reward += reward
            print('--------------------')
            print(info)
            print('--------------------')
        print("Total reward in episode {} = {}".format(e, episode_reward))

    env.close()

# %%
run_test()
# Out:
# env info:  {'state_shape': 290, 'obs_shape': 160, 'n_actions': 16, 'n_agents': 10, 'episode_limit': 150}
# (290,)
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# (290,)
# --------------------
# {'battle_won': False}
# --------------------
# Total reward in episode 0 = 2.5058112684729066

# %%
a = np.array([[1, 2], [3, 4]])
print(np.shape(a))
b = np.array([[5, 6, 8], [5, 6, 8]])
print(np.shape(b))
c = np.concatenate((a, b), axis=1)
print(c)
print(np.shape(c))
# Out:
# (2, 2)
# (2, 3)
# [[1 2 5 6 8]
#  [3 4 5 6 8]]
# (2, 5)

# %%
c = np.expand_dims(c, axis=1)

print(np.shape(c))
# Out:
# (2, 1, 5)

# %%
c2 = np.concatenate((c, c), axis=1)

# %%
print(np.shape(c2))
# Out:
# (2, 2, 5)
